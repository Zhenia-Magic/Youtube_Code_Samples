# %%
import pandas as pd
df = pd.read_csv("train-2.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.pivot_table(index=['Survived'])
# Out:
#                 Age       Fare     Parch  PassengerId    Pclass     SibSp
# Survived
# 0         30.626179  22.117887  0.329690   447.016393  2.531876  0.553734
# 1         28.343690  48.395408  0.464912   444.368421  1.950292  0.473684

# %%
df.pivot_table(index=['Survived', 'Sex'], values = 'Fare')
# Out:
#                       Fare
# Survived Sex
# 0        female  23.024385
#          male    21.960993
# 1        female  51.938573
#          male    40.821484

# %%
df.pivot_table(index='Survived', columns = 'Sex', values = 'Fare', aggfunc = ['max', 'mean'])
# Out:
#                max                 mean
# Sex         female      male     female       male
# Survived
# 0         151.5500  263.0000  23.024385  21.960993
# 1         512.3292  512.3292  51.938573  40.821484

# %%
def range_function(series):
    return max(series) - min(series)

df.pivot_table(index='Survived', columns = 'Sex', values = 'Fare', aggfunc = range_function)
# Out:
# Sex         female      male
# Survived
# 0         144.8000  263.0000
# 1         505.1042  512.3292

# %%
df.pivot_table(index=['Pclass','Sex'],  aggfunc = {'Fare': ['min','max'], 'Age' : 'mean'})
# Out:
#                      Age      Fare
#                     mean       max      min
# Pclass Sex
# 1      female  34.611765  512.3292  25.9292
#        male    41.281386  512.3292   0.0000
# 2      female  28.722973   65.0000  10.5000
#        male    30.740707   73.5000   0.0000
# 3      female  21.750000   69.5500   6.7500
#        male    26.507589   69.5500   0.0000

# %%
df.pivot_table(index='Survived', columns = 'Sex', values = 'Fare', aggfunc='count', margins = True)
# Out:
# Sex       female  male  All
# Survived
# 0             81   468  549
# 1            233   109  342
# All          314   577  891
